# %%
# %load_ext autoreload
# %autoreload 2

# %%
from agent import JinAgent
from env import JinEnv
from trainer import JinTrainer


agent1 = JinAgent()
agent2 = JinAgent()
env = JinEnv()
trainer = JinTrainer(env, agent1, agent2)
# Out:
# Setting up a new session...

# %%
trainer.train()
# Out:
# Episode 0:
#  Reward-1 = 0. Reward-2 = -1
# Loss-1 = 0.0. Loss-2 = 0.0
#
# Episode 1:
#  Reward-1 = 8. Reward-2 = 1
# Loss-1 = 0.0. Loss-2 = 0.0
#
# Episode 2:
#  Reward-1 = 0. Reward-2 = -1
# Loss-1 = 0.0. Loss-2 = 0.0
#
# Episode 3:
#  Reward-1 = 1. Reward-2 = 6
# Loss-1 = 0.0. Loss-2 = 0.0
#
# Episode 4:
#  Reward-1 = 0. Reward-2 = 3
# Loss-1 = 0.0. Loss-2 = 0.0
#
# Episode 5:
#  Reward-1 = 1. Reward-2 = 5
# Loss-1 = 0.0. Loss-2 = 0.0
#
# Episode 6:
#  Reward-1 = 4. Reward-2 = 3
# Loss-1 = 0.0. Loss-2 = 0.0
#
# Episode 7:
#  Reward-1 = 3. Reward-2 = 4
# Loss-1 = 0.0. Loss-2 = 0.0
#
# Episode 8:
#  Reward-1 = 0. Reward-2 = 0
# Loss-1 = 0.0. Loss-2 = 0.0
#
# Episode 9:
#  Reward-1 = 4. Reward-2 = 4
# Loss-1 = 0.0. Loss-2 = 0.0
#
# Episode 10:
#  Reward-1 = 1. Reward-2 = 5
# Loss-1 = 0.0. Loss-2 = 0.0
#
# Episode 11:
#  Reward-1 = 2. Reward-2 = 6
# Loss-1 = 0.0. Loss-2 = 0.0
#
# Episode 12:
#  Reward-1 = 2. Reward-2 = 5
# Loss-1 = 0.0. Loss-2 = 0.0
#
# Episode 13:
# ...
